# %% [markdown]
# # Variable Examples

# %%
# a is the variable for this statement
a = 2
b = 3  # b is the variable for this statement

# Using a arithmetic operator
c = a+b

print(c)
# Out:
# 5

# %%
a = "Bob"
b = "Cook"

c = a+b

print(c)
# Out:
# BobCook

# %%
a = "2"
b = "Cook"

c = a+b

print(c)
# Out:
# 2Cook

# %% [markdown]
# # Arithmetic operators

# %%
x = 5

# Initial value of x
print(x)

# Increase X by this value
x *= 3
print(x)
# Out:
# 5
# 15

# %%
x = 10
y = 2

z = x/y

print(z)
# Out:
# 5.0

# %%
# Modulus example

dept23AccountBalances = 10
dept23AccountBalances%=3

print(x)
# Out:
# 1

# %% [markdown]
# # Logical operators

# %%
x = 11

print(x>2 and x<=11)
# Out:
# True
